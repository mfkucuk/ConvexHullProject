# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].set_title('Algorithm Results (Uniform Distribution)')
axs[0].set_xlabel('Number of points')
axs[0].set_ylabel('Time elapsed (ms)')

axs[1].set_title('Algorithm Results (Gaussian Distribution)')
axs[1].set_xlabel('Number of points')
axs[1].set_ylabel('Time elapsed (ms)')

xpoints = np.array([500000, 600000, 700000, 800000, 900000, 1000000])

ypoints = np.array([7790, 9550, 10880, 14290, 14720, 17540])
axs[0].plot(xpoints, ypoints, label='Graham\'s Scan', color='blue')

ypoints = np.array([7650, 9270, 10750, 12090, 14460, 15440])
axs[0].plot(xpoints, ypoints, label='Jarvis\'s March', color='red')

ypoints = np.array([6400, 8320, 9640, 12020, 12230, 14470])
axs[0].plot(xpoints, ypoints, label='Quick Hull', color='green')

ypoints = np.array([9400, 10730, 12550, 13560, 16090, 17370])
axs[0].plot(xpoints, ypoints, label='Merge Hull', color='purple')
axs[0].legend()

ypoints = np.array([7750, 9500, 12390, 12760, 14440, 15460])
axs[1].plot(xpoints, ypoints, label='Graham\'s Scan', color='blue')

ypoints = np.array([7120, 8680, 10210, 11830, 14280, 14970])
axs[1].plot(xpoints, ypoints, label='Jarvis\'s March', color='red')

ypoints = np.array([6590, 8560, 9120, 10890, 12550, 13950])
axs[1].plot(xpoints, ypoints, label='Quick Hull', color='green')

ypoints = np.array([8940, 10500, 12020, 13530, 15930, 18030])
axs[1].plot(xpoints, ypoints, label='Merge Hull', color='purple')
axs[1].legend()


plt.show()
